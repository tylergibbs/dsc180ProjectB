# %%
# what vars do i want to tune (for EV)
# l1, l2, l3, threshold
def golemEV(lambda_1, lambda_2, lambda_3, thresh):
    from GOLEMTS2.model import GolemTS2
    from GOLEMTS2.generate_data import SyntheticDataset
    import GOLEMTS2.trainer as trainer
    import numpy as np
    d = 10
    p = 1
    n = 1000

    # A_init = np.random.randn((p+1) *d, d)
    dag_obj = SyntheticDataset(n=n, d=d, p=p, B_scale=1.0, graph_type='ER', degree=2, A_scale=1.0, noise_type='EV')
    model = GolemTS2(n=n, d=d, p=p, Y=dag_obj.Y, lambda_1=lambda_1, lambda_2=lambda_2, A_init=None, ev=True, lr=3e-3, lambda_3=lambda_3)
    likes, evs = trainer.train(model, dag_obj.Y, epochs=40_000, warmup_epochs=0, log=False)
    model_B = model.B.detach().numpy()
    model_B[np.abs(model_B) < thresh] = 0
    model_A = model_B[:, :d]
    return model_A, dag_obj.A

# %%
def golemEV_grid(lambda_1_l, lambda_2_l, lambda_3_l, thresh_l):
    out_list = []
    for lambda_1 in lambda_1_l:
        for lambda_2 in lambda_2_l:
            for lambda_3 in lambda_3_l:
                for thresh in thresh_l:
                    out_list.append({
                        'lambda_1': lambda_1,
                        'lambda_2': lambda_2,
                        'lambda_3': lambda_3,
                        'thresh': thresh,
                    })
    return out_list

# %%
grid = golemEV_grid(
    lambda_1_l=[1e-3, 1e-2, 1e-1],
    lambda_2_l=[0.1, 1, 5, 10],
    lambda_3_l=[0.1, 1, 5, 10],
    thresh_l=[0.01, 0.1, 0.2, 0.3]
)

# %%
import grid_search

# %%
grid_search.perform_grid_search(grid, model_func=golemEV, output_dir='golemEV03.jsonl')
# Out:
# {'fdr': 0.13333333333333333, 'tpr': 0.4482758620689655, 'fpr': 0.030303030303030304, 'shd': 34, 'pred_size': 30, 'lambda_1': 0.001, 'lambda_2': 0.1, 'lambda_3': 0.1, 'thresh': 0.01}
# {'fdr': 0.08333333333333333, 'tpr': 0.5409836065573771, 'fpr': 0.023255813953488372, 'shd': 29, 'pred_size': 36, 'lambda_1': 0.001, 'lambda_2': 0.1, 'lambda_3': 0.1, 'thresh': 0.1}
# {'fdr': 0.18181818181818182, 'tpr': 0.54, 'fpr': 0.04285714285714286, 'shd': 27, 'pred_size': 33, 'lambda_1': 0.001, 'lambda_2': 0.1, 'lambda_3': 0.1, 'thresh': 0.2}
# {'fdr': 0.1388888888888889, 'tpr': 0.6888888888888889, 'fpr': 0.034482758620689655, 'shd': 17, 'pred_size': 36, 'lambda_1': 0.001, 'lambda_2': 0.1, 'lambda_3': 0.1, 'thresh': 0.3}
# {'fdr': 0.046511627906976744, 'tpr': 0.8913043478260869, 'fpr': 0.013888888888888888, 'shd': 7, 'pred_size': 43, 'lambda_1': 0.001, 'lambda_2': 0.1, 'lambda_3': 1, 'thresh': 0.01}
# {'fdr': 0.0, 'tpr': 0.8541666666666666, 'fpr': 0.0, 'shd': 7, 'pred_size': 41, 'lambda_1': 0.001, 'lambda_2': 0.1, 'lambda_3': 1, 'thresh': 0.1}
# {'fdr': 0.0, 'tpr': 0.9090909090909091, 'fpr': 0.0, 'shd': 3, 'pred_size': 30, 'lambda_1': 0.001, 'lambda_2': 0.1, 'lambda_3': 1, 'thresh': 0.2}
# {'fdr': 0.15384615384615385, 'tpr': 0.9428571428571428, 'fpr': 0.03870967741935484, 'shd': 8, 'pred_size': 39, 'lambda_1': 0.001, 'lambda_2': 0.1, 'lambda_3': 1, 'thresh': 0.3}
# {'fdr': 0.22857142857142856, 'tpr': 0.6136363636363636, 'fpr': 0.0547945205479452, 'shd': 24, 'pred_size': 35, 'lambda_1': 0.001, 'lambda_2': 0.1, 'lambda_3': 5, 'thresh': 0.01}
# {'fdr': 0.1282051282051282, 'tpr': 0.7391304347826086, 'fpr': 0.034722222222222224, 'shd': 17, 'pred_size': 39, 'lambda_1': 0.001, 'lambda_2': 0.1, 'lambda_3': 5, 'thresh': 0.1}
# {'fdr': 0.0, 'tpr': 1.0, 'fpr': 0.0, 'shd': 0, 'pred_size': 33, 'lambda_1': 0.001, 'lambda_2': 0.1, 'lambda_3': 5, 'thresh': 0.2}
# {'fdr': 0.08108108108108109, 'tpr': 1.0, 'fpr': 0.019230769230769232, 'shd': 3, 'pred_size': 37, 'lambda_1': 0.001, 'lambda_2': 0.1, 'lambda_3': 5, 'thresh': 0.3}
# {'fdr': 0.175, 'tpr': 0.6875, 'fpr': 0.04929577464788732, 'shd': 21, 'pred_size': 40, 'lambda_1': 0.001, 'lambda_2': 0.1, 'lambda_3': 10, 'thresh': 0.01}
# {'fdr': 0.0, 'tpr': 1.0, 'fpr': 0.0, 'shd': 0, 'pred_size': 42, 'lambda_1': 0.001, 'lambda_2': 0.1, 'lambda_3': 10, 'thresh': 0.1}
# {'fdr': 0.0, 'tpr': 1.0, 'fpr': 0.0, 'shd': 0, 'pred_size': 33, 'lambda_1': 0.001, 'lambda_2': 0.1, 'lambda_3': 10, 'thresh': 0.2}
# {'fdr': 0.15625, 'tpr': 1.0, 'fpr': 0.03067484662576687, 'shd': 5, 'pred_size': 32, 'lambda_1': 0.001, 'lambda_2': 0.1, 'lambda_3': 10, 'thresh': 0.3}
# {'fdr': 0.12121212121212122, 'tpr': 0.38666666666666666, 'fpr': 0.034782608695652174, 'shd': 48, 'pred_size': 33, 'lambda_1': 0.001, 'lambda_2': 1, 'lambda_3': 0.1, 'thresh': 0.01}
# {'fdr': 0
 'pred_size': 34, 'lambda_1': 0.01, 'lambda_2': 5, 'lambda_3': 1, 'thresh': 0.1}
# {'fdr': 0.0, 'tpr': 0.9393939393939394, 'fpr': 0.0, 'shd': 2, 'pred_size': 31, 'lambda_1': 0.01, 'lambda_2': 5, 'lambda_3': 1, 'thresh': 0.2}
# {'fdr': 0.1111111111111111, 'tpr': 0.9696969696969697, 'fpr': 0.025477707006369428, 'shd': 5, 'pred_size': 36, 'lambda_1': 0.01, 'lambda_2': 5, 'lambda_3': 1, 'thresh': 0.3}
# {'fdr': 0.0, 'tpr': 0.4177215189873418, 'fpr': 0.0, 'shd': 46, 'pred_size': 33, 'lambda_1': 0.01, 'lambda_2': 5, 'lambda_3': 5, 'thresh': 0.01}
# {'fdr': 0.0, 'tpr': 1.0, 'fpr': 0.0, 'shd': 0, 'pred_size': 33, 'lambda_1': 0.01, 'lambda_2': 5, 'lambda_3': 5, 'thresh': 0.1}
# {'fdr': 0.0, 'tpr': 1.0, 'fpr': 0.0, 'shd': 0, 'pred_size': 26, 'lambda_1': 0.01, 'lambda_2': 5, 'lambda_3': 5, 'thresh': 0.2}
# {'fdr': 0.03333333333333333, 'tpr': 1.0, 'fpr': 0.006211180124223602, 'shd': 1, 'pred_size': 30, 'lambda_1': 0.01, 'lambda_2': 5, 'lambda_3': 5, 'thresh': 0.3}
# {'fdr': 0.0, 'tpr': 0.5892857142857143, 'fpr': 0.0, 'shd': 23, 'pred_size': 33, 'lambda_1': 0.01, 'lambda_2': 5, 'lambda_3': 10, 'thresh': 0.01}
# {'fdr': 0.0, 'tpr': 1.0, 'fpr': 0.0, 'shd': 0, 'pred_size': 36, 'lambda_1': 0.01, 'lambda_2': 5, 'lambda_3': 10, 'thresh': 0.1}
# {'fdr': 0.0, 'tpr': 1.0, 'fpr': 0.0, 'shd': 0, 'pred_size': 32, 'lambda_1': 0.01, 'lambda_2': 5, 'lambda_3': 10, 'thresh': 0.2}
# {'fdr': 0.03225806451612903, 'tpr': 1.0, 'fpr': 0.00625, 'shd': 1, 'pred_size': 31, 'lambda_1': 0.01, 'lambda_2': 5, 'lambda_3': 10, 'thresh': 0.3}
# {'fdr': 0.0, 'tpr': 0.6190476190476191, 'fpr': 0.0, 'shd': 24, 'pred_size': 39, 'lambda_1': 0.01, 'lambda_2': 10, 'lambda_3': 0.1, 'thresh': 0.01}
# {'fdr': 0.11764705882352941, 'tpr': 0.4, 'fpr': 0.034782608695652174, 'shd': 47, 'pred_size': 34, 'lambda_1': 0.01, 'lambda_2': 10, 'lambda_3': 0.1, 'thresh': 0.1}
# {'fdr': 0.03225806451612903, 'tpr': 0.6382978723404256, 'fpr': 0.006993006993006993, 'shd': 17, 'pred_size': 31, 'lambda_1': 0.01, 'lambda_2': 10, 'lambda_3': 0.1, 'thresh': 0.2}
# {'fdr': 0.11428571428571428, 'tpr': 0.7045454545454546, 'fpr': 0.0273972602739726, 'shd': 16, 'pred_size': 35, 'lambda_1': 0.01, 'lambda_2': 10, 'lambda_3': 0.1, 'thresh': 0.3}
# {'fdr': 0.0, 'tpr': 0.5, 'fpr': 0.0, 'shd': 34, 'pred_size': 34, 'lambda_1': 0.01, 'lambda_2': 10, 'lambda_3': 1, 'thresh': 0.01}
# {'fdr': 0.02564102564102564, 'tpr': 0.9047619047619048, 'fpr': 0.006756756756756757, 'shd': 5, 'pred_size': 39, 'lambda_1': 0.01, 'lambda_2': 10, 'lambda_3': 1, 'thresh': 0.1}
# {'fdr': 0.0, 'tpr': 0.9393939393939394, 'fpr': 0.0, 'shd': 2, 'pred_size': 31, 'lambda_1': 0.01, 'lambda_2': 10, 'lambda_3': 1, 'thresh': 0.2}
# {'fdr': 0.07894736842105263, 'tpr': 0.9459459459459459, 'fpr': 0.0196078431372549, 'shd': 5, 'pred_size': 38, 'lambda_1': 0.01, 'lambda_2': 10, 'lambda_3': 1, 'thresh': 0.3}
# {'fdr': 0.0, 'tpr': 0.4805194805194805, 'fpr': 0.0, 'shd': 40, 'pred_size': 37, 'lambda_1': 0.01, 'lambda_2': 10, 'lambda_3': 5, 'thresh': 0.01}
# {'fdr': 0.0, 'tpr': 1.0, 'fpr': 0.0, 'shd': 0, 'pred_size': 43, 'lambda_1': 0.01, 'lambda_2': 10, 'lambda_3': 5, 'thresh': 0.1}
# {'fdr': 0.0, 'tpr': 1.0, 'fpr': 0.0, 'shd': 0, 'pred_size': 34, 'lambda_1': 0.01, 'lambda_2': 10, 'lambda_3': 5, 'thresh': 0.2}
# {'fdr': 0.10256410256410256, 'tpr': 1.0, 'fpr': 0.025806451612903226, 'shd': 4, 'pred_size': 39, 'lambda_1': 0.01, 'lambda_2': 10, 'lambda_3': 5, 'thresh': 0.3}
# {'fdr': 0.0, 'tpr': 0.5, 'fpr': 0.0, 'shd': 32, 'pred_size': 32, 'lambda_1': 0.01, 'lambda_2': 10, 'lambda_3': 10, 'thresh': 0.01}
# {'fdr': 0.0, 'tpr': 1.0, 'fpr': 0.0, 'shd': 0, 'pred_size': 42, 'lambda_1': 0.01, 'lambda_2': 10, 'lambda_3': 10, 'thresh': 0.1}
# {'fdr': 0.0, 'tpr': 1.0, 'fpr': 0.0, 'shd': 0, 'pred_size': 34, 'lambda_1': 0.01, 'lambda_2': 10, 'lambda_3': 10, 'thresh': 0.2}
# {'fdr': 0.10810810810810811, 'tpr': 1.0, 'fpr': 0.025477707006369428, 'shd': 4, 'pred_size': 37, 'lambda_1': 0.01, 'lambda_2': 10, 'lambda_3': 10, 'thresh': 0.3}
# {'fdr': 1.0, 'tpr': 0.0, 'fpr': 0.20526315789473684, 'shd': 39, 'pred_size': 39, 'lambda_1': 0.1, 'lambda_2': 0.1, 'lambda_3': 0.1, 'thresh': 0.01}
# {'fdr': 0.9722222222222222, 'tpr': 1.0, 'fpr': 0.18518518518518517, 'shd': 35, 'pred_size': 36, 'lambda_1': 0.1, 'lambda_2': 0.1, 'lambda_3': 0.1, 'thresh': 0.1}
# {'fdr': 1.0, 'tpr': 0.0, 'fpr': 0.24210526315789474, 'shd': 46, 'pred_size': 46, 'lambda_1': 0.1, 'lambda_2': 0.1, 'lambda_3': 0.1, 'thresh': 0.2}
# {'fdr': 1.0, 'tpr': 0.0, 'fpr': 0.19473684210526315, 'shd': 37, 'pred_size': 37, 'lambda_1': 0.1, 'lambda_2': 0.1, 'lambda_3': 0.1, 'thresh': 0.3}
# {'fdr': 0.95, 'tpr': 1.0, 'fpr': 0.20212765957446807, 'shd': 38, 'pred_size': 40, 'lambda_1': 0.1, 'lambda_2': 0.1, 'lambda_3': 1, 'thresh': 0.01}
# {'fdr': 1.0, 'tpr': 0.0, 'fpr': 0.1631578947368421, 'shd': 31, 'pred_size': 31, 'lambda_1': 0.1, 'lambda_2': 0.1, 'lambda_3': 1, 'thresh': 0.1}
# {'fdr': 0.9705882352941176, 'tpr': 1.0, 'fpr': 0.1746031746031746, 'shd': 33, 'pred_size': 34, 'lambda_1': 0.1, 'lambda_2': 0.1, 'lambda_3': 1, 'thresh': 0.2}
# {'fdr': 0.96, 'tpr': 1.0, 'fpr': 0.12698412698412698, 'shd': 24, 'pred_size': 25, 'lambda_1': 0.1, 'lambda_2': 0.1, 'lambda_3': 1, 'thresh': 0.3}
# {'fdr': 0.9736842105263158, 'tpr': 1.0, 'fpr': 0.19576719576719576, 'shd': 37, 'pred_size': 38, 'lambda_1': 0.1, 'lambda_2': 0.1, 'lambda_3': 5, 'thresh': 0.01}
# {'fdr': 0.9736842105263158, 'tpr': 1.0, 'fpr': 0.19576719576719576, 'shd': 37, 'pred_size': 38, 'lambda_1': 0.1, 'lambda_2': 0.1, 'lambda_3': 5, 'thresh': 0.1}
# {'fdr': 0.9117647058823529, 'tpr': 1.0, 'fpr': 0.1657754010695187, 'shd': 31, 'pred_size': 34, 'lambda_1': 0.1, 'lambda_2': 0.1, 'lambda_3': 5, 'thresh': 0.2}
# {'fdr': 0.96875, 'tpr': 1.0, 'fpr': 0.164021164021164, 'shd': 31, 'pred_size': 32, 'lambda_1': 0.1, 'lambda_2': 0.1, 'lambda_3': 5, 'thresh': 0.3}
# {'fdr': 0.9722222222222222, 'tpr': 1.0, 'fpr': 0.18518518518518517, 'shd': 35, 'pred_size': 36, 'lambda_1': 0.1, 'lambda_2': 0.1, 'lambda_3': 10, 'thresh': 0.01}
# {'fdr': 0.975609756097561, 'tpr': 1.0, 'fpr': 0.21164021164021163, 'shd': 40, 'pred_size': 41, 'lambda_1': 0.1, 'lambda_2': 0.1, 'lambda_3': 10, 'thresh': 0.1}
# {'fdr': 0.9767441860465116, 'tpr': 1.0, 'fpr': 0.2222222222222222, 'shd': 42, 'pred_size': 43, 'lambda_1': 0.1, 'lambda_2': 0.1, 'lambda_3': 10, 'thresh': 0.2}
# {'fdr': 0.975609756097561, 'tpr': 1.0, 'fpr': 0.21164021164021163, 'shd': 40, 'pred_size': 41, 'lambda_1': 0.1, 'lambda_2': 0.1, 'lambda_3': 10, 'thresh': 0.3}
# {'fdr': 0
 'pred_size': 43, 'lambda_1': 0.1, 'lambda_2': 5, 'lambda_3': 10, 'thresh': 0.3}
# {'fdr': 0.19047619047619047, 'tpr': 0.8717948717948718, 'fpr': 0.052980132450331126, 'shd': 12, 'pred_size': 42, 'lambda_1': 0.1, 'lambda_2': 10, 'lambda_3': 0.1, 'thresh': 0.01}
# {'fdr': 0.20930232558139536, 'tpr': 0.8292682926829268, 'fpr': 0.06040268456375839, 'shd': 14, 'pred_size': 43, 'lambda_1': 0.1, 'lambda_2': 10, 'lambda_3': 0.1, 'thresh': 0.1}
# {'fdr': 0.2857142857142857, 'tpr': 0.8928571428571429, 'fpr': 0.06172839506172839, 'shd': 13, 'pred_size': 35, 'lambda_1': 0.1, 'lambda_2': 10, 'lambda_3': 0.1, 'thresh': 0.2}
# {'fdr': 0.3125, 'tpr': 0.9166666666666666, 'fpr': 0.060240963855421686, 'shd': 11, 'pred_size': 32, 'lambda_1': 0.1, 'lambda_2': 10, 'lambda_3': 0.1, 'thresh': 0.3}
# {'fdr': 0.0625, 'tpr': 0.8571428571428571, 'fpr': 0.012903225806451613, 'shd': 7, 'pred_size': 32, 'lambda_1': 0.1, 'lambda_2': 10, 'lambda_3': 1, 'thresh': 0.01}
# {'fdr': 0.05263157894736842, 'tpr': 0.8780487804878049, 'fpr': 0.013422818791946308, 'shd': 7, 'pred_size': 38, 'lambda_1': 0.1, 'lambda_2': 10, 'lambda_3': 1, 'thresh': 0.1}
# {'fdr': 0.11428571428571428, 'tpr': 0.9393939393939394, 'fpr': 0.025477707006369428, 'shd': 6, 'pred_size': 35, 'lambda_1': 0.1, 'lambda_2': 10, 'lambda_3': 1, 'thresh': 0.2}
# {'fdr': 0.4411764705882353, 'tpr': 1.0, 'fpr': 0.08771929824561403, 'shd': 15, 'pred_size': 34, 'lambda_1': 0.1, 'lambda_2': 10, 'lambda_3': 1, 'thresh': 0.3}
# {'fdr': 0.05128205128205128, 'tpr': 0.9736842105263158, 'fpr': 0.013157894736842105, 'shd': 3, 'pred_size': 39, 'lambda_1': 0.1, 'lambda_2': 10, 'lambda_3': 5, 'thresh': 0.01}
# {'fdr': 0.034482758620689655, 'tpr': 0.9655172413793104, 'fpr': 0.006211180124223602, 'shd': 2, 'pred_size': 29, 'lambda_1': 0.1, 'lambda_2': 10, 'lambda_3': 5, 'thresh': 0.1}
# {'fdr': 0.18181818181818182, 'tpr': 1.0, 'fpr': 0.03680981595092025, 'shd': 6, 'pred_size': 33, 'lambda_1': 0.1, 'lambda_2': 10, 'lambda_3': 5, 'thresh': 0.2}
# {'fdr': 0.4418604651162791, 'tpr': 1.0, 'fpr': 0.1144578313253012, 'shd': 19, 'pred_size': 43, 'lambda_1': 0.1, 'lambda_2': 10, 'lambda_3': 5, 'thresh': 0.3}
# {'fdr': 0.02631578947368421, 'tpr': 0.9487179487179487, 'fpr': 0.006622516556291391, 'shd': 3, 'pred_size': 38, 'lambda_1': 0.1, 'lambda_2': 10, 'lambda_3': 10, 'thresh': 0.01}
# {'fdr': 0.05263157894736842, 'tpr': 0.972972972972973, 'fpr': 0.013071895424836602, 'shd': 3, 'pred_size': 38, 'lambda_1': 0.1, 'lambda_2': 10, 'lambda_3': 10, 'thresh': 0.1}
# {'fdr': 0.15384615384615385, 'tpr': 1.0, 'fpr': 0.03821656050955414, 'shd': 6, 'pred_size': 39, 'lambda_1': 0.1, 'lambda_2': 10, 'lambda_3': 10, 'thresh': 0.2}
# {'fdr': 0.4473684210526316, 'tpr': 1.0, 'fpr': 0.10059171597633136, 'shd': 17, 'pred_size': 38, 'lambda_1': 0.1, 'lambda_2': 10, 'lambda_3': 10, 'thresh': 0.3}

# %%
# what vars do i want to tune (for EV)
# l1, l2, l3, threshold
def golemNV(lambda_1, lambda_2, lambda_3, thresh):
    from GOLEMTS2.model import GolemTS2
    from GOLEMTS2.generate_data import SyntheticDataset
    import GOLEMTS2.trainer as trainer
    import numpy as np
    d = 10
    p = 1
    n = 1000

    # A_init = np.random.randn((p+1) *d, d)
    dag_obj = SyntheticDataset(n=n, d=d, p=p, B_scale=1.0, graph_type='ER', degree=2, A_scale=1.0, noise_type='NV')
    model = GolemTS2(n=n, d=d, p=p, Y=dag_obj.Y, lambda_1=lambda_1, lambda_2=lambda_2, A_init=None, ev=False, lr=3e-3, lambda_3=lambda_3)
    likes, evs = trainer.train(model, dag_obj.Y, epochs=40_000, warmup_epochs=10_000, log=False)
    model_B = model.B.detach().numpy()
    model_B[np.abs(model_B) < thresh] = 0
    model_A = model_B[:, :d]
    return model_A, dag_obj.A
