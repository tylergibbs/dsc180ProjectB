# %%
import testing_two

# %%
testing_two.test_all_methods(output_dir='testing07.jsonl')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 testing_two.test_all_methods(output_dir='testing07.jsonl')
#
# File ~/Documents/GitHub/dsc180ProjectB/testing_two.py:125, in test_all_methods(output_dir)
#     122 for dag_obj, dag_stat in zip(dag_list, dag_stats):
#     123     # get estimated dag
#     124     start = time.time()
# --> 125     A_est = func(dag_obj)
#     126     end = time.time()
#     127     elapsed = end - start
#
# File ~/Documents/GitHub/dsc180ProjectB/testing_two.py:21, in dynotears(dag_obj)
#      20 def dynotears(dag_obj):
# ---> 21     return run_dynotears.learn_dag(dag_obj)
#
# File ~/Documents/GitHub/dsc180ProjectB/DYNOTEARS/run_dynotears.py:16, in learn_dag(dag_obj, w_thresh)
#      14 def learn_dag(dag_obj, w_thresh=0.01):
#      15     X_lag = dag_obj.Y[:, dag_obj.d:]
# ...
