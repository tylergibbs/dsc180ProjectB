# %%
import testing

# %%
testing.test_all_methods(output_dir='testing01.jsonl')
# Out:
# {'fdr': 0.43478260869565216, 'tpr': 0.7222222222222222, 'fpr': 0.37037037037037035, 'shd': 14, 'pred_size': 23, 'n': 50, 'p': 1, 'd': 5, 'degree': 2, 'noise_type': 'EV', 'mlp': True, 'runtime': 0.3151369094848633, 'model_name': 'DYNOTEARS'}
# {'fdr': 0.4090909090909091, 'tpr': 0.5652173913043478, 'fpr': 0.4090909090909091, 'shd': 17, 'pred_size': 22, 'n': 50, 'p': 1, 'd': 5, 'degree': 2, 'noise_type': 'EV', 'mlp': True, 'runtime': 0.3572990894317627, 'model_name': 'DYNOTEARS'}
# {'fdr': 0.45, 'tpr': 0.6111111111111112, 'fpr': 0.3333333333333333, 'shd': 14, 'pred_size': 20, 'n': 50, 'p': 1, 'd': 5, 'degree': 2, 'noise_type': 'EV', 'mlp': True, 'runtime': 0.3530130386352539, 'model_name': 'DYNOTEARS'}
# {'fdr': 0.42105263157894735, 'tpr': 0.55, 'fpr': 0.32, 'shd': 15, 'pred_size': 19, 'n': 50, 'p': 1, 'd': 5, 'degree': 2, 'noise_type': 'EV', 'mlp': True, 'runtime': 0.18312907218933105, 'model_name': 'DYNOTEARS'}
# ...
